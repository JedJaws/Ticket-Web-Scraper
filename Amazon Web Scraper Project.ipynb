# %%
from bs4 import BeautifulSoup
import requests
import time
from time import strftime, localtime
import datetime
import csv

import smtplib

# %%
URL = 'https://gametime.co/the-basement-yard-experience-tickets/performers/comedybasementyard'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html data-reactroot="" data-type="" lang="en">
# <head>
# <title data-react-helmet="true">
#    Cheap The Basement Yard Experience Tickets | Gametime
#   </title>
# <meta charset="utf-8" data-react-helmet="true"/>
# <meta content="en" data-react-helmet="true" http-equiv="Content-Language"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" data-react-helmet="true" name="viewport"/>
# <meta content="yes" data-react-helmet="true" name="mobile-web-app-capable"/>
# <meta content="yes" data-react-helmet="true" name="apple-mobile-web-app-capable"/>
# <meta content="Gametime" data-react-helmet="true" name="application-name"/>
# <meta content="Gametime" data-react-helmet="true" name="apple-mobile-web-app-title"/>
# <meta content="Q9Kc1RFSykmuI-JdxHtvu-hf1fmAwus-9ITqGvhcDKQ" data-react-helmet="true" name="google-site-verification"/>
# ...

# %%
date1 = soup2.find_all('div', class_ = '_1ysyENgK_zeITUBkyqcnZZ')[0].get_text().strip()
date1
# Out:
# '8/1'

# %%
price1 = soup2.find_all('div', class_ = '_2ca-mVuLkbb6Y_QOP6482K')[0].get_text().strip()
price1 = int(price1[1:-1])
price1
# Out:
# 107

# %%
date2 = soup2.find_all('div', class_ = '_1ysyENgK_zeITUBkyqcnZZ')[2].get_text().strip()
date2
# Out:
# '8/2'

# %%
price2 = soup2.find_all('div', class_ = '_2ca-mVuLkbb6Y_QOP6482K')[1].get_text().strip()
price2 = int(price2[1:-1])
price2
# Out:
# 55

# %%
today = datetime.date.today()
print(today)
# Out:
# 2024-04-13

# %%
import csv

header = ['Show Date', 'Price', 'Date Checked']
show1 = [date1, price1, today]
show2 = [date2, price2, today]

with open('BasementYardPrices.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(show1)
    writer.writerow(show2)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\JedPo\BasementYardPrices.csv')

print(df)
# Out:
#   Show Date  Price Date Checked
# 0       8/1    107   2024-04-13
# 1       8/2     55   2024-04-13

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('jedpoy@gmail.com', 'livingthegoodlife')

    subject = "Basement Yard Tickets are below 70!"
    body = "One of the days has gone below $70, I would buy a ticket and count your luck!"
    msg = f"Subject: {subject}\n\n{body}"

    server.sendmail(
        'jedpoy@gmail.com',
        msg
    )

# %%
def check_price():
    URL = 'https://gametime.co/the-basement-yard-experience-tickets/performers/comedybasementyard'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    date1 = soup2.find_all('div', class_ = '_1ysyENgK_zeITUBkyqcnZZ')[0].get_text().strip()
    price1 = soup2.find_all('div', class_ = '_2ca-mVuLkbb6Y_QOP6482K')[0].get_text().strip()
    price1 = int(price1[1:-1])

    date2 = soup2.find_all('div', class_ = '_1ysyENgK_zeITUBkyqcnZZ')[2].get_text().strip()
    price2 = soup2.find_all('div', class_ = '_2ca-mVuLkbb6Y_QOP6482K')[1].get_text().strip()
    price2 = int(price2[1:-1])

    today = datetime.date.today()
    time_now = datetime.now()
    time = time_now.strftime("%H:%M:%S")

    header = ['Show Date', 'Price', 'Date Checked', 'Time']
    show1 = [date1, price1, today, time]
    show2 = [date2, price2, today, time]
    
    with open('BasementYardPrices.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(show1)
        writer.writerow(show2)

    #if(price1 < 70 or price2 < 70):
        #send_mail()

# %%
while(True):
    check_price()
    time.sleep(3600)
    print('Checked')
# Out:
# Checked
# Checked
# Checked
# Checked
# Checked
# Checked
# Checked
# Checked
# Checked
# Checked
# Checked

# %%
df = pd.read_csv(r'C:\Users\JedPo\BasementYardPrices.csv')
print(df)
